# %%
# %sql
USE CATALOG fintech_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

-- COMMAND ----------
-- SILVER 1: Fact Table - Insider Transactions (MAIN)

OPTIMIZE silver.silver_fact_insider_transactions
ZORDER BY (company_name, filing_date);

ANALYZE TABLE silver.silver_fact_insider_transactions
COMPUTE STATISTICS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- COMMAND ----------
-- SILVER 2: Fact Table - Institutional Holdings

OPTIMIZE silver.silver_fact_institutional_holdings
ZORDER BY (company_name, filing_date);

ANALYZE TABLE silver.silver_fact_institutional_holdings
COMPUTE STATISTICS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- COMMAND ----------
-- SILVER 3: Dimension - Companies

OPTIMIZE silver.silver_dim_companies
ZORDER BY (company_name);

ANALYZE TABLE silver.silver_dim_companies
COMPUTE STATISTICS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- COMMAND ----------
-- SILVER 4: Dimension - Insiders

OPTIMIZE silver.silver_dim_insiders
ZORDER BY (insider_name);

ANALYZE TABLE silver.silver_dim_insiders
COMPUTE STATISTICS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- COMMAND ----------
-- SILVER 5: Dimension - Institutions

OPTIMIZE silver.silver_dim_institutions
ZORDER BY (cik);

ANALYZE TABLE silver.silver_dim_institutions
COMPUTE STATISTICS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
